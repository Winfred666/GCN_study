# %% [markdown]
# ### Test program
# train the graph data, visualize result , and set proper hyper parameters using cross validation.

# %%
from cite_data_process import load_siteseer
import numpy as np
import  scipy.sparse as sp
import torch

# %reload_ext autoreload
# %autoreload 2

adj, features, labels, train_masks, val_masks, test_mask = load_siteseer("citeseer")
print("Citeseer data set:\nAdjacency matrix is sparse: ", sp.issparse(adj))
print("All labels are one hot encoding: ", labels[0])
print("Each node has high dimentional feature: ", features.shape[1])
print("Total number of nodes: ", adj.shape[0])
print("Number of training nodes: ", train_masks[0].sum())
print("Number of validation nodes: ", val_masks[0].sum())
print("Number of testing nodes: ", test_mask.sum())

# convert labels from one-hot encoding to integer
class_num = labels.shape[1]
labels = np.argmax(labels, axis=1)
# Out:
# Citeseer data set:
# Adjacency matrix is sparse:  True
# All labels are one hot encoding:  [0. 0. 0. 1. 0. 0.]
# Each node has high dimentional feature:  3703
# Total number of nodes:  3327
# Number of training nodes:  496
# Number of validation nodes:  124
# Number of testing nodes:  1000

# %%
# now try to train GCN model
from train import train_base

layer_dims = [features.shape[1],16,class_num]
print("Layer dimensions: ", layer_dims)
# the first layer will be big like 3703 neuron with 3703*F weight
base_model, acc_list, loss_list = train_base(
    layer_dims=layer_dims,
    data=(adj, features, labels, train_masks[0], val_masks[0] ))
# Out:
# Layer dimensions:  [3703, 16, 6]
# Using device: cuda
# layer_dims: [3703, 16, 6],
# dropout_rate: 0.2,
# learning_rate: 0.01,
# weight_decay: 0.0001,
# epoch_num: 200,
# self_importance: 1.0,
# laplace_norm: True
# Epoch: 0, Loss: 1.7945, Train Set Acc: 0.5423, Validate Set Acc: 0.2742
# Epoch: 10, Loss: 1.6013, Train Set Acc: 0.8508, Validate Set Acc: 0.5645
# Epoch: 20, Loss: 1.3493, Train Set Acc: 0.8871, Validate Set Acc: 0.6129
# Epoch: 30, Loss: 1.1189, Train Set Acc: 0.8911, Validate Set Acc: 0.6532
# Epoch: 40, Loss: 0.9440, Train Set Acc: 0.8952, Validate Set Acc: 0.6532
# Epoch: 50, Loss: 0.8112, Train Set Acc: 0.9093, Validate Set Acc: 0.6210
# Epoch: 60, Loss: 0.7094, Train Set Acc: 0.9194, Validate Set Acc: 0.6935
# Epoch: 70, Loss: 0.6165, Train Set Acc: 0.9496, Validate Set Acc: 0.6694
# Epoch: 80, Loss: 0.5620, Train Set Acc: 0.9496, Validate Set Acc: 0.7016
# Epoch: 90, Loss: 0.5135, Train Set Acc: 0.9556, Validate Set Acc: 0.6855
# Epoch: 100, Loss: 0.4921, Train Set Acc: 0.9657, Validate Set Acc: 0.6774
# Epoch: 110, Loss: 0.4614, Train Set Acc: 0.9617, Validate Set Acc: 0.6774
# Epoch: 120, Loss: 0.4371, Train Set Acc: 0.9657, Validate Set Acc: 0.7339
# Epoch: 130, Loss: 0.4158, Train Set Acc: 0.9677, Validate Set Acc: 0.6371
# Epoch: 140, Loss: 0.3908, Train Set Acc: 0.9637, Validate Set Acc: 0.6371
# Epoch: 150, Loss: 0.3869, Train Set Acc: 0.9698, Validate Set Acc: 0.6613
# Epoch: 160, Loss: 0.3691, Train Set Acc: 0.9698, Validate Set Acc: 0.6935
# Epoch: 170, Loss: 0.3595, Train Set Acc: 0.9677, Validate Set Acc: 0.6532
# Epoch: 180, Loss: 0.3520, Train Set Acc: 0.9778, Validate Set Acc: 0.6855
# Epoch: 190, Loss: 0.3503, Train Set Acc: 0.9758, Validate Set Acc: 0.6855
